# %% [markdown]
# # REINFORCE on PastureEnv
# This notebook implements a simple episodic REINFORCE (policy gradient) agent for the custom `PastureEnv`, logs results to CSV, plots metrics, and renders the best policy.

# %%
import os, sys, json, time, random, csv
from pathlib import Path
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
from custom_env import make_env
from eval_utils import evaluate_policy
from stable_baselines3 import PPO
from stable_baselines3.ppo.policies import MlpPolicy as PPOMlpPolicy
MODELS_DIR =  Path('models') / 'reinforce'
MODELS_DIR.mkdir(parents=True, exist_ok=True)

# %%
# 2) Reproducibility and Run Metadata
SEED = 42
np.random.seed(SEED)
random.seed(SEED)
torch.manual_seed(SEED)
run_meta = {
    'algo': 'REINFORCE',
    'seed': SEED,
    'env': 'PastureEnv',
    'timestamp': time.strftime('%Y-%m-%d %H:%M:%S')
}
with open(MODELS_DIR / 'run_meta.json', 'w') as f: json.dump(run_meta, f, indent=2)
run_meta
# Out:
# {'algo': 'REINFORCE',
#  'seed': 42,
#  'env': 'PastureEnv',
#  'timestamp': '2025-11-24 11:27:25'}

# %%
from dataclasses import dataclass
import torch.nn as nn
from typing import List


@dataclass
class ReinforceConfig:
    learning_rate: float = 1e-3
    gamma: float = 0.99
    hidden_size: int = 128
    entropy_coef: float = 0.01

class ReinforcePolicy(nn.Module):
    def __init__(self, obs_dim: int, act_dim: int, hidden: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_dim, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, act_dim)
        )
    def forward(self, x):
        return self.net(x)
    def predict(self, obs):
        with torch.no_grad():
            x = torch.from_numpy(obs).float().unsqueeze(0)
            logits = self.forward(x)
            probs = torch.softmax(logits, dim=-1)
            dist = torch.distributions.Categorical(probs)
            return dist.sample().item()

def compute_returns(rewards: List[float], gamma: float) -> List[float]:
    G = 0.0; out = []
    for r in reversed(rewards):
        G = r + gamma * G
        out.append(G)
    return list(reversed(out))

# %%
from collections import Counter
def eval_policy(policy, episodes=5):
    env_fn = lambda: make_env(render_mode=None)
    stats = evaluate_policy(env_fn, policy, episodes=episodes)
    env = env_fn()
    counts = Counter()
    ep_rewards = []
    for _ in range(episodes):
        obs, _ = env.reset()
        done, trunc = False, False
        total = 0.0
        while not (done or trunc):
            action = policy.predict(obs)
            counts[int(action)] += 1
            obs, r, done, trunc, info = env.step(int(action))
            total += r
        ep_rewards.append(total)
    env.close()
    action_counts = [counts.get(i, 0) for i in range(5)]
    return stats, action_counts, ep_rewards

# %%
# Hyperparameters and Training Loop
TOTAL_EPISODES = 10000
EVAL_EPISODES = 5
RUN_LIMIT = None
grid = {
    'learning_rate': [1e-3, 5e-4],
    'gamma': [0.95, 0.99],
    'hidden_size': [64, 128],
    'entropy_coef': [0.0, 0.01],
}
from itertools import product
import torch.optim as optim
keys = list(grid.keys())
combos = [dict(zip(keys, vals)) for vals in product(*[grid[k] for k in keys])]
if RUN_LIMIT is not None: combos = combos[:RUN_LIMIT]
def train_run(params: dict, run_id: int):
    env = make_env(render_mode=None)
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n
    policy = ReinforcePolicy(obs_dim, act_dim, params['hidden_size'])
    optimizer = optim.Adam(policy.parameters(), lr=params['learning_rate'])
    baseline = None
    all_returns = []
    for ep in range(1, TOTAL_EPISODES + 1):
        obs, _ = env.reset()
        done = False; trunc = False
        ep_rewards = []
        ep_log_probs = []
        ep_entropies = []
        while not (done or trunc):
            x = torch.from_numpy(obs).float().unsqueeze(0)
            logits = policy(x)
            probs = torch.softmax(logits, dim=-1)
            dist = torch.distributions.Categorical(probs)
            action = dist.sample()
            log_prob = dist.log_prob(action)
            entropy = dist.entropy().mean()
            nxt, r, done, trunc, info = env.step(int(action.item()))
            ep_rewards.append(r)
            ep_log_probs.append(log_prob)
            ep_entropies.append(entropy)
            obs = nxt
        returns = compute_returns(ep_rewards, params['gamma'])
        returns_t = torch.tensor(returns, dtype=torch.float32)
        if baseline is None: baseline = returns_t.mean().item()
        baseline = 0.9 * baseline + 0.1 * returns_t.mean().item()
        adv = returns_t - baseline
        loss = -(torch.stack(ep_log_probs) * adv.detach()).mean() - params['entropy_coef'] * torch.stack(ep_entropies).mean()
        optimizer.zero_grad(); loss.backward(); optimizer.step()
        all_returns.append(sum(ep_rewards))
        if ep % 50 == 0:
            print(f"[REINFORCE Run {run_id}] Episode {ep}/{TOTAL_EPISODES} avg_last50={np.mean(all_returns[-50:]):.2f}")
    env.close()
    return policy
models_dir = MODELS_DIR
runs_csv = models_dir / 'reinforce_runs.csv'
episodes_csv = models_dir / 'reinforce_episodes.csv'
def ensure_csv_headers(file, headers):
    if not file.exists():
        with open(file, 'w', newline='') as f:
            csv.writer(f).writerow(headers)
ensure_csv_headers(runs_csv, ['run_id','timestamp','params','avg_reward','std_reward','avg_length','mean_hunger','mean_thirst','grazing_balance','best','time_sec'])
ensure_csv_headers(episodes_csv, ['run_id','episode','reward'])
best_mean = -1e9
best_path = None
run_id = 0
for params in combos:
    run_id += 1
    t0 = time.time()
    policy = train_run(params, run_id)
    stats, action_counts, ep_rewards = eval_policy(policy, episodes=EVAL_EPISODES)
    mean_reward = stats.get('avg_reward', float(np.mean(ep_rewards)))
    is_best = ''
    if mean_reward > best_mean:
        best_mean = mean_reward
        best_path = models_dir / 'best_reinforce.pt'
        torch.save({'state_dict': policy.state_dict(), 'config': params}, best_path)
        is_best = 'yes'
    with open(runs_csv, 'a', newline='') as f:
        csv.writer(f).writerow([run_id, time.strftime('%Y-%m-%d %H:%M:%S'), str(params), stats.get('avg_reward'), stats.get('std_reward'), stats.get('avg_length'), stats.get('mean_hunger'), stats.get('mean_thirst'), stats.get('grazing_balance_mean'), is_best, f'{time.time()-t0:.1f}'])
    with open(episodes_csv, 'a', newline='') as f:
        w = csv.writer(f)
        for i, r in enumerate(ep_rewards, 1):
            w.writerow([run_id, i, r])
best_path
# Out:
# [REINFORCE Run 1] Episode 50/10000 avg_last50=34.18
# [REINFORCE Run 1] Episode 100/10000 avg_last50=111.51
# [REINFORCE Run 1] Episode 150/10000 avg_last50=141.83
# [REINFORCE Run 1] Episode 200/10000 avg_last50=108.70
# [REINFORCE Run 1] Episode 250/10000 avg_last50=163.98
# [REINFORCE Run 1] Episode 300/10000 avg_last50=195.31
# [REINFORCE Run 1] Episode 350/10000 avg_last50=195.93
# [REINFORCE Run 1] Episode 400/10000 avg_last50=236.30
# [REINFORCE Run 1] Episode 450/10000 avg_last50=172.89
# [REINFORCE Run 3] Episode 1650/10000 avg_last50=351.94
# [REINFORCE Run 3] Episode 1700/10000 avg_last50=290.81
# [REINFORCE Run 3] Episode 1750/10000 avg_last50=334.92
# [REINFORCE Run 3] Episode 1800/10000 avg_last50=347.15
# [REINFORCE Run 3] Episode 1850/10000 avg_last50=345.92
# [REINFORCE Run 3] Episode 1900/10000 avg_last50=356.10
# [REINFORCE Run 3] Episode 1950/10000 avg_last50=359.93
# [REINFORCE Run 3] Episode 2000/10000 avg_last50=349.50
# [REINFORCE Run 3] Episode 2050/10000 avg_last50=355.31
# [REINFORCE Run 3] Episode 2100/10000 avg_last50=363.44
# [REINFORCE Run 3] Episode 2150/10000 avg_last50=367.67
# [REINFORCE Run 3] Episode 2200/10000 avg_last50=369.75
# [REINFORCE Run 3] Episode 2250/10000 avg_last50=370.15
# [REINFORCE Run 3] Episode 2300/10000 avg_last50=345.42
# [REINFORCE Run 3] Episode 2350/10000 avg_last50=373.57
# [REINFORCE Run 3] Episode 2400/10000 avg_last50=371.98
# [REINFORCE Run 3] Episode 2450/10000 avg_last50=373.89
# [REINFORCE Run 3] Episode 2500/10000 avg_last50=373.29
# [REINFORCE Run 3] Episode 2550/10000 avg_last50=380.59
# [REINFORCE Run 3] Episode 2600/10000 avg_last50=381.81
# [REINFORCE Run 3] Episode 2650/10000 avg_last50=383.51
# [REINFORCE Run 3] Episode 2700/10000 avg_last50=378.26
# [REINFORCE Run 3] Episode 2750/10000 avg_last50=381.32
# [REINFORCE Run 3] Episode 2800/10000 avg_last50=385.02
# [REINFORCE Run 3] Episode 2850/10000 avg_last50=388.66
# [REINFORCE Run 3] Episode 2900/10000 avg_last50=383.69
# [REINFORCE Run 3] Episode 2950/10000 avg_last50=386.95
# [REINFORCE Run 3] Episode 3000/10000 avg_last50=387.10
# [REINFORCE Run 3] Episode 3050/10000 avg_last50=383.90
# [REINFORCE Run 3] Episode 3100/10000 avg_last50=384.67
# [REINFORCE Run 3] Episode 3150/10000 avg_last50=388.43
# [REINFORCE Run 3] Episode 3200/10000 avg_last50=390.08
# [REINFORCE Run 3] Episode 3250/10000 avg_last50=390.95
# [REINFORCE Run 3] Episode 3300/10000 avg_last50=385.66
# [REINFORCE Run 3] Episode 3350/10000 avg_last50=389.84
# [REINFORCE Run 3] Episode 3400/10000 avg_last50=391.83
# [REINFORCE Run 3] Episode 3450/10000 avg_last50=392.51
# [REINFORCE Run 3] Episode 3500/10000 avg_last50=394.74
# [REINFORCE Run 3] Episode 3550/10000 avg_last50=390.01
# [REINFORCE Run 3] Episode 3600/10000 avg_last50=390.76
# [REINFORCE Run 3] Episode 3650/10000 avg_last50=392.56
# [REINFORCE Run 3] Episode 3700/10000 avg_last50=395.39
# [REINFORCE Run 3] Episode 3750/10000 avg_last50=393.93
# [REINFORCE Run 3] Episode 3800/10000 avg_last50=388.54
# [REINFORCE Run 3] Episode 3850/10000 avg_last50=392.86
# [REINFORCE Run 3] Episode 3900/10000 avg_last50=391.64
# [REINFORCE Run 3] Episode 3950/10000 avg_last50=361.28
# [REINFORCE Run 3] Episode 6350/10000 avg_last50=398.20
# [REINFORCE Run 3] Episode 6400/10000 avg_last50=402.43
# [REINFORCE Run 3] Episode 6450/10000 avg_last50=395.19
# [REINFORCE Run 3] Episode 6500/10000 avg_last50=401.10
# [REINFORCE Run 3] Episode 6550/10000 avg_last50=397.18
# [REINFORCE Run 3] Episode 6600/10000 avg_last50=402.41
# [REINFORCE Run 3] Episode 6650/10000 avg_last50=401.95
# [REINFORCE Run 3] Episode 6700/10000 avg_last50=401.03
# [REINFORCE Run 3] Episode 6750/10000 avg_last50=403.63
# [REINFORCE Run 3] Episode 6800/10000 avg_last50=401.87
# [REINFORCE Run 3] Episode 6850/10000 avg_last50=399.60
# [REINFORCE Run 3] Episode 6900/10000 avg_last50=402.86
# [REINFORCE Run 3] Episode 6950/10000 avg_last50=403.27
# [REINFORCE Run 3] Episode 7000/10000 avg_last50=391.64
# [REINFORCE Run 3] Episode 7050/10000 avg_last50=399.02
# [REINFORCE Run 3] Episode 7100/10000 avg_last50=400.06
# [REINFORCE Run 3] Episode 7150/10000 avg_last50=401.38
# [REINFORCE Run 3] Episode 7200/10000 avg_last50=401.81
# [REINFORCE Run 3] Episode 7250/10000 avg_last50=404.91
# [REINFORCE Run 3] Episode 7300/10000 avg_last50=397.77
# [REINFORCE Run 3] Episode 7350/10000 avg_last50=400.58
# [REINFORCE Run 3] Episode 7400/10000 avg_last50=391.82
# [REINFORCE Run 3] Episode 7450/10000 avg_last50=407.85
# [REINFORCE Run 3] Episode 7500/10000 avg_last50=402.46
# [REINFORCE Run 3] Episode 7550/10000 avg_last50=386.96
# [REINFORCE Run 3] Episode 7600/10000 avg_last50=399.42
# [REINFORCE Run 3] Episode 7650/10000 avg_last50=397.20
# [REINFORCE Run 3] Episode 7700/10000 avg_last50=393.72
# [REINFORCE Run 3] Episode 7750/10000 avg_last50=397.32
# [REINFORCE Run 3] Episode 7800/10000 avg_last50=397.92
# [REINFORCE Run 3] Episode 7850/10000 avg_last50=397.07
# [REINFORCE Run 3] Episode 7900/10000 avg_last50=402.03
# [REINFORCE Run 3] Episode 7950/10000 avg_last50=397.81
# [REINFORCE Run 3] Episode 8000/10000 avg_last50=402.52
# [REINFORCE Run 3] Episode 8050/10000 avg_last50=405.53
# [REINFORCE Run 3] Episode 8100/10000 avg_last50=402.26
# [REINFORCE Run 3] Episode 8150/10000 avg_last50=401.21
# [REINFORCE Run 3] Episode 8200/10000 avg_last50=405.39
# [REINFORCE Run 3] Episode 8250/10000 avg_last50=401.24
# [REINFORCE Run 3] Episode 8300/10000 avg_last50=403.37
# [REINFORCE Run 3] Episode 8350/10000 avg_last50=393.80
# [REINFORCE Run 3] Episode 8400/10000 avg_last50=400.61
# [REINFORCE Run 3] Episode 8450/10000 avg_last50=401.09
# [REINFORCE Run 3] Episode 8500/10000 avg_last50=403.33
# [REINFORCE Run 3] Episode 8550/10000 avg_last50=403.97
# [REINFORCE Run 3] Episode 8600/10000 avg_last50=394.72
# [REINFORCE Run 3] Episode 8650/10000 avg_last50=399.12
# [REINFORCE Run 16] Episode 1850/10000 avg_last50=325.78
# [REINFORCE Run 16] Episode 1900/10000 avg_last50=313.80
# [REINFORCE Run 16] Episode 1950/10000 avg_last50=304.92
# [REINFORCE Run 16] Episode 2000/10000 avg_last50=318.28
# [REINFORCE Run 16] Episode 2050/10000 avg_last50=325.56
# [REINFORCE Run 16] Episode 2100/10000 avg_last50=324.15
# [REINFORCE Run 16] Episode 2150/10000 avg_last50=333.57
# [REINFORCE Run 16] Episode 2200/10000 avg_last50=344.18
# [REINFORCE Run 16] Episode 2250/10000 avg_last50=332.92
# [REINFORCE Run 16] Episode 2300/10000 avg_last50=327.59
# [REINFORCE Run 16] Episode 2350/10000 avg_last50=335.32
# [REINFORCE Run 16] Episode 2400/10000 avg_last50=325.34
# [REINFORCE Run 16] Episode 2450/10000 avg_last50=333.19
# [REINFORCE Run 16] Episode 2500/10000 avg_last50=315.57
# [REINFORCE Run 16] Episode 2550/10000 avg_last50=298.79
# [REINFORCE Run 16] Episode 2600/10000 avg_last50=343.36
# [REINFORCE Run 16] Episode 2650/10000 avg_last50=356.38
# [REINFORCE Run 16] Episode 2700/10000 avg_last50=353.81
# [REINFORCE Run 16] Episode 2750/10000 avg_last50=362.39
# [REINFORCE Run 16] Episode 2800/10000 avg_last50=359.38
# [REINFORCE Run 16] Episode 2850/10000 avg_last50=355.25
# [REINFORCE Run 16] Episode 2900/10000 avg_last50=356.99
# [REINFORCE Run 16] Episode 2950/10000 avg_last50=351.86
# [REINFORCE Run 16] Episode 3000/10000 avg_last50=361.15
# [REINFORCE Run 16] Episode 3050/10000 avg_last50=368.65
# [REINFORCE Run 16] Episode 3100/10000 avg_last50=365.57
# [REINFORCE Run 16] Episode 3150/10000 avg_last50=368.67
# [REINFORCE Run 16] Episode 3200/10000 avg_last50=365.46
# [REINFORCE Run 16] Episode 3250/10000 avg_last50=336.30
# [REINFORCE Run 16] Episode 3300/10000 avg_last50=364.79
# [REINFORCE Run 16] Episode 3350/10000 avg_last50=368.89
# [REINFORCE Run 16] Episode 3400/10000 avg_last50=373.09
# [REINFORCE Run 16] Episode 3450/10000 avg_last50=373.03
# [REINFORCE Run 16] Episode 3500/10000 avg_last50=372.88
# [REINFORCE Run 16] Episode 3550/10000 avg_last50=374.67
# [REINFORCE Run 16] Episode 3600/10000 avg_last50=372.46
# [REINFORCE Run 16] Episode 3650/10000 avg_last50=372.16
# [REINFORCE Run 16] Episode 3700/10000 avg_last50=381.27
# [REINFORCE Run 16] Episode 3750/10000 avg_last50=373.20
# [REINFORCE Run 16] Episode 3800/10000 avg_last50=376.89
# [REINFORCE Run 16] Episode 3850/10000 avg_last50=376.70
# [REINFORCE Run 16] Episode 3900/10000 avg_last50=374.74
# [REINFORCE Run 16] Episode 3950/10000 avg_last50=384.54
# [REINFORCE Run 16] Episode 4000/10000 avg_last50=384.21
# [REINFORCE Run 16] Episode 4050/10000 avg_last50=378.22
# [REINFORCE Run 16] Episode 4100/10000 avg_last50=375.51
# [REINFORCE Run 16] Episode 4150/10000 avg_last50=378.85
# [REINFORCE Run 16] Episode 4200/10000 avg_last50=382.07
# [REINFORCE Run 16] Episode 4250/10000 avg_last50=378.38
# [REINFORCE Run 16] Episode 4300/10000 avg_last50=386.56
# [REINFORCE Run 16] Episode 4350/10000 avg_last50=383.41
# [REINFORCE Run 16] Episode 4400/10000 avg_last50=380.73
# [REINFORCE Run 16] Episode 4450/10000 avg_last50=383.51
# [REINFORCE Run 16] Episode 4500/10000 avg_last50=382.94
# [REINFORCE Run 16] Episode 4550/10000 avg_last50=383.81
# [REINFORCE Run 16] Episode 4600/10000 avg_last50=381.48
# [REINFORCE Run 16] Episode 4650/10000 avg_last50=382.67
# [REINFORCE Run 16] Episode 4700/10000 avg_last50=383.85
# [REINFORCE Run 16] Episode 4750/10000 avg_last50=384.90
# [REINFORCE Run 16] Episode 4800/10000 avg_last50=389.25
# [REINFORCE Run 16] Episode 4850/10000 avg_last50=391.06
# [REINFORCE Run 16] Episode 4900/10000 avg_last50=385.21
# [REINFORCE Run 16] Episode 4950/10000 avg_last50=390.43
# [REINFORCE Run 16] Episode 5000/10000 avg_last50=387.57
# [REINFORCE Run 16] Episode 5050/10000 avg_last50=388.48
# [REINFORCE Run 16] Episode 5100/10000 avg_last50=389.03
# [REINFORCE Run 16] Episode 5150/10000 avg_last50=392.40
# [REINFORCE Run 16] Episode 5200/10000 avg_last50=389.68
# [REINFORCE Run 16] Episode 5250/10000 avg_last50=383.22
# [REINFORCE Run 16] Episode 5300/10000 avg_last50=388.03
# [REINFORCE Run 16] Episode 5350/10000 avg_last50=392.48
# [REINFORCE Run 16] Episode 5400/10000 avg_last50=391.87
# [REINFORCE Run 16] Episode 5450/10000 avg_last50=391.79
# [REINFORCE Run 16] Episode 5500/10000 avg_last50=388.23
# [REINFORCE Run 16] Episode 5550/10000 avg_last50=391.08
# [REINFORCE Run 16] Episode 5600/10000 avg_last50=396.17
# [REINFORCE Run 16] Episode 5650/10000 avg_last50=394.04
# [REINFORCE Run 16] Episode 5700/10000 avg_last50=392.91
# [REINFORCE Run 16] Episode 5750/10000 avg_last50=393.48
# [REINFORCE Run 16] Episode 5800/10000 avg_last50=386.67
# [REINFORCE Run 16] Episode 5850/10000 avg_last50=394.25
# [REINFORCE Run 16] Episode 5900/10000 avg_last50=385.05
# [REINFORCE Run 16] Episode 5950/10000 avg_last50=392.78
# [REINFORCE Run 16] Episode 6000/10000 avg_last50=393.93
# [REINFORCE Run 16] Episode 6050/10000 avg_last50=393.41
# [REINFORCE Run 16] Episode 6100/10000 avg_last50=394.52
# [REINFORCE Run 16] Episode 6150/10000 avg_last50=394.87
# [REINFORCE Run 16] Episode 6200/10000 avg_last50=391.44
# [REINFORCE Run 16] Episode 6250/10000 avg_last50=393.77
# [REINFORCE Run 16] Episode 6300/10000 avg_last50=396.65
# [REINFORCE Run 16] Episode 6350/10000 avg_last50=391.09
# [REINFORCE Run 16] Episode 6400/10000 avg_last50=393.31
# [REINFORCE Run 16] Episode 6450/10000 avg_last50=395.43
# [REINFORCE Run 16] Episode 6500/10000 avg_last50=392.52
# [REINFORCE Run 16] Episode 6550/10000 avg_last50=398.64
# [REINFORCE Run 16] Episode 6600/10000 avg_last50=398.85
# [REINFORCE Run 16] Episode 6650/10000 avg_last50=393.32
# [REINFORCE Run 16] Episode 6700/10000 avg_last50=395.89
# [REINFORCE Run 16] Episode 6750/10000 avg_last50=393.20
# [REINFORCE Run 16] Episode 6800/10000 avg_last50=398.34
# [REINFORCE Run 16] Episode 6850/10000 avg_last50=394.01
# [REINFORCE Run 16] Episode 6900/10000 avg_last50=396.51
# [REINFORCE Run 16] Episode 6950/10000 avg_last50=392.90
# [REINFORCE Run 16] Episode 7000/10000 avg_last50=396.72
# [REINFORCE Run 16] Episode 7050/10000 avg_last50=399.08
# [REINFORCE Run 16] Episode 7100/10000 avg_last50=397.20
# [REINFORCE Run 16] Episode 7150/10000 avg_last50=393.88
# [REINFORCE Run 16] Episode 7200/10000 avg_last50=397.71
# [REINFORCE Run 16] Episode 7250/10000 avg_last50=397.56
# [REINFORCE Run 16] Episode 7300/10000 avg_last50=395.51
# [REINFORCE Run 16] Episode 7350/10000 avg_last50=393.90
# [REINFORCE Run 16] Episode 7400/10000 avg_last50=399.15
# [REINFORCE Run 16] Episode 7450/10000 avg_last50=397.15
# [REINFORCE Run 16] Episode 7500/10000 avg_last50=389.84
# [REINFORCE Run 16] Episode 7550/10000 avg_last50=393.90
# [REINFORCE Run 16] Episode 7600/10000 avg_last50=395.39
# [REINFORCE Run 16] Episode 7650/10000 avg_last50=398.49
# [REINFORCE Run 16] Episode 7700/10000 avg_last50=398.39
# [REINFORCE Run 16] Episode 7750/10000 avg_last50=399.44
# [REINFORCE Run 16] Episode 7800/10000 avg_last50=395.40
# [REINFORCE Run 16] Episode 7850/10000 avg_last50=389.97
# [REINFORCE Run 16] Episode 7900/10000 avg_last50=395.36
# [REINFORCE Run 16] Episode 7950/10000 avg_last50=395.69
# [REINFORCE Run 16] Episode 8000/10000 avg_last50=395.25
# [REINFORCE Run 16] Episode 8050/10000 avg_last50=395.26
# [REINFORCE Run 16] Episode 8100/10000 avg_last50=397.44
# [REINFORCE Run 16] Episode 8150/10000 avg_last50=389.46
# [REINFORCE Run 16] Episode 8200/10000 avg_last50=396.03
# [REINFORCE Run 16] Episode 8250/10000 avg_last50=398.34
# [REINFORCE Run 16] Episode 8300/10000 avg_last50=401.15
# [REINFORCE Run 16] Episode 8350/10000 avg_last50=403.57
# [REINFORCE Run 16] Episode 8400/10000 avg_last50=399.79
# [REINFORCE Run 16] Episode 8450/10000 avg_last50=398.40
# [REINFORCE Run 16] Episode 8500/10000 avg_last50=400.73
# [REINFORCE Run 16] Episode 8550/10000 avg_last50=401.02
# [REINFORCE Run 16] Episode 8600/10000 avg_last50=402.67
# [REINFORCE Run 16] Episode 8650/10000 avg_last50=401.27
# [REINFORCE Run 16] Episode 8700/10000 avg_last50=397.84
# [REINFORCE Run 16] Episode 8750/10000 avg_last50=402.40
# [REINFORCE Run 16] Episode 8800/10000 avg_last50=398.09
# [REINFORCE Run 16] Episode 8850/10000 avg_last50=401.71
# [REINFORCE Run 16] Episode 8900/10000 avg_last50=392.05
# [REINFORCE Run 16] Episode 8950/10000 avg_last50=399.04
# [REINFORCE Run 16] Episode 9000/10000 avg_last50=394.02
# [REINFORCE Run 16] Episode 9050/10000 avg_last50=403.62
# [REINFORCE Run 16] Episode 9100/10000 avg_last50=401.56
# [REINFORCE Run 16] Episode 9150/10000 avg_last50=400.88
# [REINFORCE Run 16] Episode 9200/10000 avg_last50=399.30
# [REINFORCE Run 16] Episode 9250/10000 avg_last50=404.03
# [REINFORCE Run 16] Episode 9300/10000 avg_last50=402.22
# [REINFORCE Run 16] Episode 9350/10000 avg_last50=398.74
# [REINFORCE Run 16] Episode 9400/10000 avg_last50=399.10
# [REINFORCE Run 16] Episode 9450/10000 avg_last50=400.83
# [REINFORCE Run 16] Episode 9500/10000 avg_last50=401.55
# [REINFORCE Run 16] Episode 9550/10000 avg_last50=403.01
# [REINFORCE Run 16] Episode 9600/10000 avg_last50=403.87
# [REINFORCE Run 16] Episode 9650/10000 avg_last50=396.86
# [REINFORCE Run 16] Episode 9700/10000 avg_last50=395.28
# [REINFORCE Run 16] Episode 9750/10000 avg_last50=398.58
# [REINFORCE Run 16] Episode 9800/10000 avg_last50=398.21
# [REINFORCE Run 16] Episode 9850/10000 avg_last50=399.48
# [REINFORCE Run 16] Episode 9900/10000 avg_last50=396.88
# [REINFORCE Run 16] Episode 9950/10000 avg_last50=400.27
# [REINFORCE Run 16] Episode 10000/10000 avg_last50=401.52
# PosixPath('models/reinforce/best_reinforce.pt')

# %%
runs_csv = MODELS_DIR / 'reinforce' / 'reinforce_runs.csv'
episodes_csv = MODELS_DIR / 'reinforce' / 'reinforce_episodes.csv'
if runs_csv.exists():
    runs = pd.read_csv(runs_csv)
    display(runs.tail())
    plt.figure(figsize=(7,4))
    plt.plot(runs['avg_reward'], marker='o')
    plt.title('REINFORCE sweep: mean reward per run')
    plt.xlabel('run idx')
    plt.ylabel('avg_reward')
    plt.grid(True, alpha=0.3)
    plt.show()
if episodes_csv.exists():
    eps = pd.read_csv(episodes_csv)
    plt.figure(figsize=(7,4))
    for rid, df in eps.groupby('run_id'):
        plt.plot(df['episode'], df['reward'], alpha=0.5)
    plt.title('Per-episode rewards across runs (REINFORCE)')
    plt.xlabel('episode')
    plt.ylabel('reward')
    plt.grid(True, alpha=0.3)
    plt.show()

# %%
# 7) Visualize Best Model
from pathlib import Path
best_path = MODELS_DIR / 'best_reinforce.pt'
if Path(best_path).exists():
    env = make_env(render_mode=None, render_fps=10)
    # Load saved model
    ckpt = torch.load(best_path, map_location='cpu')
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n
    hidden = ckpt.get('config', {}).get('hidden_size', 128)
    policy = ReinforcePolicy(obs_dim, act_dim, hidden)
    policy.load_state_dict(ckpt['state_dict'])
    policy.eval()
    obs, _ = env.reset()
    done = False; trunc = False; total = 0.0
    while not (done or trunc):
        action = policy.predict(obs)
        obs, r, done, trunc, info = env.step(int(action))
        total += r
        env.render()
    env.close()
    print('Episode reward:', total)
else:
    print('Best model not found yet. Run training first.')
# Out:
# Episode reward: 407.84884188771224
